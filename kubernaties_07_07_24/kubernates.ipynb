# %%
# !pwd
# Out:
# /home/lithira/Project1/kubernaties_07_07_24

# %%
# !kubectl apply -f namespace.yaml

# %%
# !kubectl apply -f persistent-volume.yaml

# %%
# !kubectl apply -f persistent-volume-claim.yaml

# %%
# !kubectl apply -f deployment.yaml

# %%
# !kubectl apply -f service.yaml

# %%
# !kubectl get pods

# %%
# !kubectl get services

# %%
# !minikube service ml-app-service

# %%
import requests

# Define the URL to the Flask server
url = 'http://<service-url>/process_video'  # Replace <service-url> with the actual service URL obtained from Minikube

# Path to the video file you want to upload
video_path = 'show.mp4'

# Open the video file in binary mode
with open(video_path, 'rb') as video_file:
    # Create a dictionary to hold the file data
    files = {'video': video_file}
    
    # Send a POST request with the video file
    response = requests.post(url, files=files)

# Print the server's response
print(response.status_code)
print(response.text)

# %%
# !kubectl get pods

# %%
# !kubectl logs <pod-name>

# %%
# !kubectl logs -f <pod-name>

# %% [markdown]
# 2nd

# %%
# !minikube start --driver docker --container-runtime docker --gpus all
# Out:
# 😄  minikube v1.33.1 on Ubuntu 22.04 (amd64)
# ✨  Using the docker driver based on existing profile
# 👍  Starting "minikube" primary control-plane node in "minikube" cluster
# 🚜  Pulling base image v0.0.44 ...
# 🔄  Restarting existing docker container for "minikube" ...
# 🐳  Preparing Kubernetes v1.30.0 on Docker 26.1.1 ...
# 🔎  Verifying Kubernetes components...
#     ▪ Using image nvcr.io/nvidia/k8s-device-plugin:v0.15.0
#     ▪ Using image gcr.io/k8s-minikube/storage-provisioner:v5
#     ▪ Using image docker.io/kubernetesui/metrics-scraper:v1.0.8
#     ▪ Using image docker.io/kubernetesui/dashboard:v2.7.0
# 💡  Some dashboard features require the metrics-server addon. To enable all features please run:
#
# 	minikube addons enable metrics-server
#
# 🌟  Enabled addons: nvidia-device-plugin, storage-provisioner, dashboard, default-storageclass
# 🏄  Done! kubectl is now configured to use "minikube" cluster and "default" namespace by default

# %%
# !kubectl apply -f gpu-pod.yaml
# Out:
# pod/gpu-operator-test created

# %%
# !kubectl apply -f ml-app-pv.yaml
# Out:
# persistentvolume/ml-app-pv created

# %%
# !kubectl apply -f ml-app-pvc.yaml
# Out:
# persistentvolumeclaim/ml-app-pvc created

# %%
# !kubectl apply -f ml-app-deployment.yaml
# Out:
# deployment.apps/ml-app created

# %%
# !kubectl apply -f ml-app-service.yaml
# Out:
# service/ml-app-service unchanged

# %%
import requests

# Define the URL to the Flask server
url = 'http://127.0.0.1:33195/process_video'

# Path to the video file you want to upload
video_path = 'show.mp4'

# Open the video file in binary mode
with open(video_path, 'rb') as video_file:
    # Create a dictionary to hold the file data
    files = {'video': video_file}
    
    # Send a POST request with the video file
    response = requests.post(url, files=files)

# Print the server's response
print(response.status_code)
print(response.text)
# Out:
# 200
# Processing completed.

# %%
# !minikube service ml-app-service --url
# Out:
# http://127.0.0.1:45271
# ❗  Because you are using a Docker driver on linux, the terminal needs to be open to run it.
# ^C

# %%
import requests

# Get the Minikube service URL (run this in your terminal and replace the URL below)
# minikube service ml-app-service --url

url = 'http://127.0.0.1:34369/process_video'  # Replace with your actual Minikube service URL

# Path to the video file you want to upload
video_path = 'show.mp4'

# Open the video file in binary mode
with open(video_path, 'rb') as video_file:
    # Create a dictionary to hold the file data
    files = {'video': video_file}
    
    # Send a POST request with the video file
    response = requests.post(url, files=files)

# Print the server's response
print(response.status_code)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 17
#      14     files = {'video': video_file}
#      16     # Send a POST request with the video file
# ---> 17     response = requests.post(url, files=files)
#      19 # Print the server's response
#      20 print(response.status_code)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
# ...

# %%
import requests

# Get the Minikube service URL (run this in your terminal and replace the URL below)
# minikube service ml-app-service --url

url = 'http://127.0.0.1:44167/process_video'  # Replace with your actual Minikube service URL

# Path to the video file you want to upload
video_path = 'show.mp4'

# Open the video file in binary mode
with open(video_path, 'rb') as video_file:
    # Create a dictionary to hold the file data
    files = {'video': video_file}
    
    # Send a POST request with the video file
    response = requests.post(url, files=files)

# Print the server's response
print(response.status_code)
print(response.text)

# %%
# !kubectl apply -f nvidia-device-plugin-config.yaml
# Out:
# configmap/nvidia-device-plugin-config created

# %%
# !kubectl apply -f nvidia-device-plugin-daemonset.yaml
# Out:
# daemonset.apps/nvidia-device-plugin-daemonset configured

# %%
# !kubectl apply -f mps-configmap.yaml
# Out:
# configmap/mps-config configured

# %%
# !kubectl apply -f mps-daemonset.yaml
# Out:
# daemonset.apps/nvidia-mps-daemonset configured
